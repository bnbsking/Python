# %%
import re
# re.match(pattern, target).group() # return one match string from first character
# re.match(pattern, target).span()  # return one match index(tuple) from first character
# re.search(pattern, target).group()  # return one match string
# re.search(pattern, target).span()   # return one match index(tuple)
# re.findall(pattern, target)        # return all match string in list
# re.finditer(pattern, target)       # return all match in generator G. ele.group() or ele.span()

# or pattern = re.compile(pattern); pattern.findall(target) # verbose 
# pattern: *:0~n times, +:1~n times, .:1 time, {n,m}:n~m times, [a-z]:a~z permutations

# %%
print(re.findall('a*b*', 'aabb'))
print(re.findall('b.*', 'abab'))
print(re.findall('[0-9]', 'afj3i293ubr1kjn'))
# Out:
# ['aabb', '']
# ['bab']
# ['3', '2', '9', '3', '1']

# %%
re.findall("\w*@(.+)\.", "hello@yahoo.com.tw"), re.findall("\w*@(.+?)\.", "hello@yahoo.com.tw")
# Out:
# (['yahoo.com'], ['yahoo'])

# %%
# . any character except for linebreak
# ^abc article head match (must return 0 or 1 item)
# abc$ article tail match (must return 0 or 1 item)
# [^abc] any character exclude character a,b,c
# a(bcd)e take parenthesis part only (bcd)
# a.+ max matching (default)
# a.? least matching (at least 1)
# a(?!xy)[a-z] means a[a-z] but exclude string axy # Negative lookahead # Doesn't has the meaning of 'taking parenthesis part only'
# \w = [a-zA-Z0-9_]
# \d = [0-9]
# \s = [ \t\n]
