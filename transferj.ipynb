# %%
import warnings; warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np

All = {\
    'Python':['趨勢', '用途', '特性', '環境安裝 O', '基礎資料型態 O', '流程控制 O', '高等資料型態 O',
        '函數 O', '類別 O', '引用 O', '外部參數腳本 O', '可執行檔 O', 'Git版本控制 O'],
    'AI':['歷史', 'AI-ML-DL', '演算法類型', '標準流程', 'DL實務類型', '回歸 O', '分類 O', '聚類 O',
        '降維 O', '生成 O'],
    '資料結構演算法':['演算法定義', '複雜度', '遞迴 O', '動態規劃 O', '雜湊 O', '排序 O', '堆疊及佇列 O',
        '鏈結串列 O', '樹 O', '圖 O'],
    '資料庫管理系統':['資料庫分類', '資料結構及搜尋原理', '正規化', '安全性', 
        'DB-server O', 'DB-client O', 'SQL O'],
    '計算機組織結構':['電腦分層', '主機板與指令集', '馮紐曼架構', '高階轉低階', '處理器', '記憶體',
        '磁碟', '組裝電腦 O'],
    '作業系統':['程序狀態轉換圖', 'CPU排程演算法', '多執行序 O', '互斥控制', '死結問題', '記憶體管理',
        'Windows O', 'Linux O', '虛擬機器 O', 'Docker O'],
    '數學':['數列級數 O', '指對數 O', '機率統計', 'Entropy', '矩陣運算 O', '矩陣基底', 'FFT O',\
        'SVD O'],
    '計算機網路':['硬體架構', 'OSI-TCP/IP', 'Link O', 'IP O', 'TCP O', 'APP O']}
dfa = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in All.items() ]))
dfa.replace(np.nan, ' ')
# Out:
#        Python        AI  資料結構演算法      資料庫管理系統  計算機組織結構       作業系統       數學  \
# 0          趨勢        歷史    演算法定義        資料庫分類     電腦分層    程序狀態轉換圖   數列級數 O
# 1          用途  AI-ML-DL      複雜度    資料結構及搜尋原理  主機板與指令集   CPU排程演算法    指對數 O
# 2          特性     演算法類型     遞迴 O          正規化    馮紐曼架構     多執行序 O     機率統計
# 3      環境安裝 O      標準流程   動態規劃 O          安全性    高階轉低階       互斥控制  Entropy
# 4    基礎資料型態 O    DL實務類型     雜湊 O  DB-server O      處理器       死結問題   矩陣運算 O
# 5      流程控制 O      回歸 O     排序 O  DB-client O      記憶體      記憶體管理     矩陣基底
# 6    高等資料型態 O      分類 O  堆疊及佇列 O        SQL O       磁碟  Windows O    FFT O
# 7        函數 O      聚類 O   鏈結串列 O                組裝電腦 O    Linux O    SVD O
# 8        類別 O      降維 O      樹 O                           虛擬機器 O
# 9        引用 O      生成 O      圖 O                         Docker O
# 10   外部參數腳本 O
# 11     可執行檔 O
# 12  Git版本控制 O
#
#          計算機網路
# 0         硬體架構
# 1   OSI-TCP/IP
# 2       Link O
# 3         IP O
# 4        TCP O
# ...

# %%
L=['UML', '通訊協定', 'WEB前後端', 'PC-APP-UI', 'Mobile-APP-UI', '嵌入式系統', '邊緣計算',\
   '雲端計算', '攔截封包', '逆向工程', '韌體工程', '系統工程', 'MIS', '密碼學', '數位邏輯設計', 'PLC',
   '...']
for item in L: print(item, end=' ')
# Out:
# UML 通訊協定 WEB前後端 PC-APP-UI Mobile-APP-UI 嵌入式系統 邊緣計算 雲端計算 攔截封包 逆向工程 韌體工程 系統工程 MIS 密碼學 數位邏輯設計 PLC ...
